# %% [markdown]
# first way to do it...

# %%
a= input("seq: ")
rev=""
final=""
for i in a:
    rev= i + rev
for j in rev:
    if j=="G":
        final+= "C"
    elif j=="C":
        final+= "G"
    elif j=="A":
        final+= "T"
    elif j=="T":
        final+= "A"
print(final)
# Out:
# seq: ...
# ...

# %% [markdown]
# second way...

# %%
a="..."
b=a[::-1]
b=b.replace("A","t").replace("T","a").replace("G","c").replace("C","g").upper()
print(b)
# Out:
# ...
