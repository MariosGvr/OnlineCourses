# %%
first_seq= input("FIRST sequence= ")
second_seq= input("SECOND sequence= ")
dh=0

for i in range(0,len(first_seq)):
    if first_seq[i] != second_seq[i]:
        dh+= 1
        
print(dh)
# Out:
# FIRST sequence= ...
# SECOND sequence= ...
# 470
